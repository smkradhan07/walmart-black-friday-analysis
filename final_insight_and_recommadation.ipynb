# %%
print("""
RECOMMENDATIONS

1.Focus ads on 26–45 age group
2.Stock more premium products in City B & C
3.Offer spending threshold discounts
4.Segment campaigns by gender
5.Create loyalty tiers for high spenders
""")
# Out:
# RECOMMENDATIONS
#
# 1.Focus ads on 26–45 age group
# 2.Stock more premium products in City B & C
# 3.Offer spending threshold discounts
# 4.Segment campaigns by gender
# 5.Create loyalty tiers for high spenders
