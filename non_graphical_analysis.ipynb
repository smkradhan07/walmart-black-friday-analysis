# %%
#import the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

#Load Dataset
walmart = pd.read_csv("walmart_data.csv")
walmart.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17        10.0             A
# 1  1000001  P00248942      F  0-17        10.0             A
# 2  1000001  P00087842      F  0-17        10.0             A
# 3  1000001  P00085442      F  0-17        10.0             A
# 4  1000002  P00285442      M   55+        16.0             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category  Purchase
# 0                          2             0.0               3.0    8370.0
# 1                          2             0.0               1.0   15200.0
# 2                          2             0.0              12.0    1422.0
# 3                          2             0.0              12.0    1057.0
# 4                         4+             0.0               8.0    7969.0

# %%
#Question2: Non Graphical Analysis

print("Unique Age Groups:", walmart['Age'].unique())
# Out:
# Unique Age Groups: ['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25', NaN]
# Categories (7, object): ['0-17', '18-25', '26-35', '36-45', '46-50', '51-55', '55+']

# %%
print("\nGender Distribution:\n", walmart['Gender'].value_counts())
# Out:
# Gender Distribution:
#  Gender
# M    202899
# F     66161
# Name: count, dtype: int64

# %%
print("\nMarital Status Distribution:\n", walmart['Marital_Status'].value_counts())
# Out:
# Marital Status Distribution:
#  Marital_Status
# 0.0    158897
# 1.0    110162
# Name: count, dtype: int64
